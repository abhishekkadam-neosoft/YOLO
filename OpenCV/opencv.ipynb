# %%
import cv2

# %% [markdown]
# # Creating Bounding Box Manually

# %%
import matplotlib.pyplot as plt

image_path = "Media.jpeg"
image = cv2.imread(image_path)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Define bounding box coordinates (x_min, y_min, x_max, y_max)
x_min, y_min = 150, 1000  # Top-left corner
x_max, y_max = 2100, 2300  # Bottom-right corner

# Draw the bounding box (Rectangle)
color = (0, 255, 0)  # Green color (BGR format)
thickness = 20
cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color, thickness)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2

image_path = "Media.jpeg"
image = cv2.imread(image_path)

image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2

image_path = "Media.jpeg"
image = cv2.imread(image_path)

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (21,21), 0)   # Larger values = Stronger blur (removes more details and noise).
                                            # Smaller values = Weaker blur (preserves more details).

# _, binary = cv2.threshold(blur, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

binary = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

plt.imshow(image)
plt.axis("off")
plt.show()
